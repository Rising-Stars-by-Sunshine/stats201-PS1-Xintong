# %% [markdown]
# **References**: https://github.com/blockchain-etl/ethereum-etl

# %% [markdown]
# # Problem Set 1 Checklist

# %% [markdown]
# **Please customize the following inputs to generate your own results for discussion**
#
#
# * Infura/Alchemy/QuickNode API endpoints: experiment with multiple node operators and see if you could get the same data
#
# * Data radius, start, and end blocks: pick a smaller radius for testing before you scale
#
# * Token address: Pick your choice of token in querying the token transfer part
#
# **Please post the sharing (Allow viewing or commenting only) URL for your Google Colab after you are done below.**
#
# Important: Change your private API token key to "API_KEY" before posting

# %% [markdown]
# ## Question 1 (5 points)
# Did you get the same data querying via different node operators? Please point to at least one specific observation to validate your answer.
#
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# Yes.I got the same data querying via different node operators. I compared their "number" and "nonce" values to see if they are the same.
#
# Infura
# ![1.jpg](data:image/jpeg;base64,...)
#
# Alchemy
# ![2.jpg](data:image/jpeg;base64,...)
#
# Quicknode
# ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question 2 (5 points)

# %% [markdown]
# Please introduce the ERC20 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *   what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# Dai stablecoin firstly was issued in December 2017. (Coinbase 2022)
# The token is a decentralized collateral-backed stablecoin that intends to keep its value near or equal to 1 dollor. Dai is currently used in mortgage lending, margin trading, international money transfers, supply chain finance and other areas.
# Dai’s price today is US 1.01 dollor, with a 24-hour trading volume of $214.94 M. (Crypto 2022)
#
# Here is the 24h price chart.
# ![dai.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Article**
#
# Schär, F. (2021). Decentralized finance: On blockchain-and smart contract-based financial markets. *FRB of St. Louis Review.*
#
# **Background/Motivation**
#
# The term decentralized finance (DeFi) uses smart contracts to create protocols that replicate existing financial services in a more open, interoperable, and transparent manner, but its decentralized transactions still carry many risks.
#
# **Research question**
#
# What are the development opportunities and potential risks of the DeFi ecosystem?
#
# **Application scenarios**
#
# The DeFi ecosystem in Ethernet.
#
# **Methodology**
#
# This paper presents a conceptual framework for analyzing the multi-layered structure of DeFi and examines the token and protocol layers in more detail.
#
# **Results**
#
# DeFi is a niche market with some risks, but it also has practical properties in terms of efficiency, transparency, accessibility, and composability.
#
# **Intellectual merits/ practical impacts**
#
# This study finds great potential in this technology, but also some risks. To achieve "decentralization", many protocols and applications should use external data sources and special management keys to manage the system. In the future, DeFi may lead to a paradigm shift in the financial industry and may contribute to a more robust, open, and transparent financial infrastructure.

# %% [markdown]
# ### Question 3: (5 points)
#
# Please introduce the ERC721 token that you queried in 100 words:
#
#
# *   when the token first was issued?
# *   what functions do the token support?
# *  what is the current market value of the token?
# *   Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer.
# Please insert Figures/Tables to better represent your idea.

# %% [markdown]
# ENS was started at the Ethereum Foundation in early 2017. (Coinbase 2022)
# Ethereum Name Service is a decentralized and extensible naming system based on the Ethereum blockchain. It offers a secure & decentralized way to address resources both on and off the blockchain using simple, human-readable names. (Ethrscan 2022)
# ENS’s price today is US 15.35 dollor, with a 24-hour trading volume of $87.88 M. (Crypto 2022)
#
# Here is the 24h price chart.
# ![ens.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Article**
#
# Tan, Y., Wu, Z., Liu, J., Wu, J., Zheng, Z., & Chen, T. (2023). Bubble or Not: Measurements, Analyses, and Findings on the Ethereum ERC721 and ERC1155 Non-fungible Token Ecosystem. *arXiv preprint arXiv:2301.01991.*
#
# **Background/Motivation**
#
# Non-Fungible Tokens (NFTs) have experienced a volatile trading market after their IPO, and doubts have been raised about the apparent boom in NFTs. There is no comprehensive and systematic study of the NFT trading market or the NFT bubble and hype phenomenon.
#
# **Research question**
#
# How to effectively identify bubble NFT?
#
# **Application scenarios**
#
# Ethernet ERC721 and ERC1155 NFT ecosystem.
#
# **Methodology**
#
# Graphical analysis. NFT creation graphs, NFT delivery graphs, and NFT holding graphs were constructed to characterize NFT traders, analyze NFT characteristics, and discover many observations and insights.
#
# **Results**
#
# By using bubble NFT labels, we can analyze the characteristics and trading patterns of bubble NFT traders and thus better guide NFT investments.
#
# **Intellectual merits/ practical impacts**
#
# This study proposes new metrics to quantify the activity and value of NFT and proposes an algorithm that combines metrics and graph analysis to identify bubble NFTs. In the future, it is hoped to enhance the bubble NFT detection algorithm by adding more comprehensive features and enabling it to detect other types of bubble NFTs, such as scam NFTs and NFTs created by automated programs.

# %% [markdown]
# # Part I: Install Required Dependancies

# %%
# install ethereum-etl and pandas
# !python -m pip install ethereum-etl pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 KB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.8/501.8 KB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 KB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 KB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 KB 9.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Part II: Mount Google Drive for Result Exports

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the current directory
# !pwd
# Out:
# /content

# %%
#@title path
#create a project folder and identify the path
path = "/content/drive/MyDrive/EthereumETL" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content/drive/MyDrive/EthereumETL
# Out:
# /content/drive/MyDrive/EthereumETL

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content/drive/MyDrive/EthereumETL

# %% [markdown]
# # Part III: Query Data and Export CSV

# %% [markdown]
# ## 0.Register Accounts on Remote Nodes Service and Get the URLs of the Nodes

# %% [markdown]
# ### Remote node option 1: Infura

# %% [markdown]
# !!! Important Notes: Please replace https://mainnet.infura.io/v3/API_KEY with your own endpoints for all the codes below

# %%
#@title Import using the Infura node
infura_end_points_URL = "https://mainnet.infura.io/v3/d7ec1252cc2a4031848d6d1963b443a6" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 2: Alchemy

# %%
#@title import using Alchemy
alchemy_end_points_URL = "https://eth-mainnet.g.alchemy.com/v2/hTkQoD1QuW8jeifl62CP9X9gEXuroY0c" #@param {type:"string"}

# %% [markdown]
# ### Remote node option 3: QuickNode

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://morning-palpable-lake.discover.quiknode.pro/8cc483a0fd23460df4538b0e753b52062ce3be94/" #@param {type:"string"}

# %% [markdown]
# Data Range: We are going to query the block and transaction data for the ethereum blockchain before and after the merge (block number: 15537393 on September 15)
#
# Reference;
# https://www.investopedia.com/ethereum-completes-the-merge-6666337

# %%
#@title the merge
merge = 15537393 #@param {type:"number"}

# %%
#@title data radius
radius = 5 #@param {type:"number"}

# %%
### find the start and the end
start = merge-radius
end = merge+radius
print(start, end)
# Out:
# 15537388 15537398

# %% [markdown]
# ## 1. Query Block Data

# %% [markdown]
# ### using the infura endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537388 --end-block 15537398 --blocks-output blocks.csv --provider-uri https://mainnet.infura.io/v3/d7ec1252cc2a4031848d6d1963b443a6
# Out:
# 2023-01-26 08:33:09,501 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:33:10,124 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:33:10,124 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:00.623252.
# 2023-01-26 08:33:10,125 - CompositeItemExporter [INFO] - block items exported: 11
# 2023-01-26 08:33:10,125 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
# import libraries to print data frame
import pandas as pd

# %%
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
df_blocks = pd.read_csv('./blocks.csv')
display(df_blocks.head(10))
# Out:
#      number                                               hash  \
# 0  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 1  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 2  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 3  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 4  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
# 5  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 6  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 7  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 8  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
# 9  15537397  0x9797d65f12465ada68cdacf7e6b7c22fe43a4d096711...
#
#                                          parent_hash               nonce  \
# 0  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...  0x9206e9a5cae2058c
# 1  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...  0xebba2908368ba3fb
# ...

# %% [markdown]
# ### query blockchain data using the alchemy endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537388 --end-block 15537398 --blocks-output blocks_alchemy.csv --provider-uri https://eth-mainnet.g.alchemy.com/v2/hTkQoD1QuW8jeifl62CP9X9gEXuroY0c
# Out:
# 2023-01-26 08:33:30,467 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:33:30,733 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:33:30,734 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:00.266384.
# 2023-01-26 08:33:30,735 - CompositeItemExporter [INFO] - block items exported: 11
# 2023-01-26 08:33:30,735 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_alchemy = pd.read_csv('./blocks_alchemy.csv')
display(df_blocks_alchemy.head(10))
# Out:
#      number                                               hash  \
# 0  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 1  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 2  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 3  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 4  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
# 5  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 6  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 7  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 8  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
# 9  15537397  0x9797d65f12465ada68cdacf7e6b7c22fe43a4d096711...
#
#                                          parent_hash               nonce  \
# 0  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...  0x9206e9a5cae2058c
# 1  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...  0xebba2908368ba3fb
# ...

# %% [markdown]
# ### query the data using the QuickNode endpoint

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537388 --end-block 15537398 --blocks-output blocks_QuickNode.csv --provider-uri https://morning-palpable-lake.discover.quiknode.pro/8cc483a0fd23460df4538b0e753b52062ce3be94/
# Out:
# 2023-01-26 08:33:43,843 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:33:44,368 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:33:44,369 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:00.525675.
# 2023-01-26 08:33:44,370 - CompositeItemExporter [INFO] - block items exported: 11
# 2023-01-26 08:33:44,370 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_QuickNode = pd.read_csv('./blocks_QuickNode.csv')
display(df_blocks_QuickNode.head(10))
# Out:
#      number                                               hash  \
# 0  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 1  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 2  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 3  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 4  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
# 5  15537393  0x55b11b918355b1ef9c5db810302ebad0bf2544255b53...
# 6  15537394  0x56a9bb0302da44b8c0b3df540781424684c3af04d0b7...
# 7  15537395  0xe37e1a183a3d1c7234d090bfb7196081635919c26f2e...
# 8  15537396  0x98c735877f2f30bad54fc46ba8bcd93a54da32a60b29...
# 9  15537397  0x9797d65f12465ada68cdacf7e6b7c22fe43a4d096711...
#
#                                          parent_hash               nonce  \
# 0  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...  0x9206e9a5cae2058c
# 1  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...  0xebba2908368ba3fb
# ...

# %% [markdown]
# ## 2. Query Transaction Data

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537388 --end-block 15537398 --transactions-output transactions.csv --provider-uri https://mainnet.infura.io/v3/d7ec1252cc2a4031848d6d1963b443a6
# Out:
# 2023-01-26 08:33:55,252 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:33:56,303 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:33:56,303 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:01.051547.
# 2023-01-26 08:33:56,303 - CompositeItemExporter [INFO] - block items exported: 0
# 2023-01-26 08:33:56,305 - CompositeItemExporter [INFO] - transaction items exported: 1140

# %%
df_transactions = pd.read_csv('./transactions.csv')
display(df_transactions.head())
# Out:
#                                                 hash  nonce  \
# 0  0x1ccbdb9913d35d7f870ba1822159ae4ca1f660faa208...      0
# 1  0x414e84145408904ac945a108ab946edcec19185a2c94...    113
# 2  0xc3decb6a4a09de496947b85da6f0195ce8ee3afceb9e...   1280
# 3  0xe72ef9baee086d62ded0f80e124d01c7f703f9a46d65...     13
# 4  0xd82e5c7f0392e94c5228f4e0bdb827212a9e84463849...   9108
#
#                                           block_hash  block_number  \
# 0  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...      15537388
# 1  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...      15537388
# 2  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...      15537388
# 3  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...      15537388
# 4  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...      15537388
#
#    transaction_index                                from_address  \
# 0                  0  0xb6d44ba99e6e31ca00a888a5232ff332b0d607a3
# 1                  1  0x87033ad96757ecd730aa1652b1a7dabcc5ffb182
# ...

# %% [markdown]
# ## 3. Query Token Data

# %% [markdown]
# ### 3.1 Query All Token Transfers

# %%
# !ethereumetl export_token_transfers --start-block 15537388 --end-block 15537398 --provider-uri https://eth-mainnet.g.alchemy.com/v2/hTkQoD1QuW8jeifl62CP9X9gEXuroY0c --output token_transfers.csv
# Out:
# 2023-01-26 08:34:08,440 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:34:18,456 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:34:18,456 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:10.016173.
# 2023-01-26 08:34:18,458 - CompositeItemExporter [INFO] - token_transfer items exported: 30889

# %%
df_token_transfers = pd.read_csv('./token_transfers.csv')
display(df_token_transfers.head())
# Out:
#                                 token_address  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1  0x397abdfb6ec12e6fa24d84cbabb1505157a5caac
# 2  0x397abdfb6ec12e6fa24d84cbabb1505157a5caac
# 3  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                  from_address  \
# 0  0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45
# 1  0x8a84c20c27d8e55a4e54ce19db0b1be4a05c6720
# 2  0x8a84c20c27d8e55a4e54ce19db0b1be4a05c6720
# 3  0x0000000000000000000000000000000000000000
# 4  0x5720eb958685deeeb5aa0b34f677861ce3a8c7f5
#
#                                    to_address                          value  \
# 0  0x8a84c20c27d8e55a4e54ce19db0b1be4a05c6720             150000000000000000
# 1  0x397abdfb6ec12e6fa24d84cbabb1505157a5caac   2169959720320717682633283658
# 2  0x87033ad96757ecd730aa1652b1a7dabcc5ffb182  52079033287697224383198807811
# 3  0x4ffb72b66eba24521736924f87dfe10677d82286                           6172
# ...

# %%
df = df_token_transfers[df_token_transfers.token_address=="0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a"]
df.head()
# Out:
#                                  token_address  \
# 3   0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 11  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 12  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 13  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
# 14  0x7bc25283a29a3888cab4555ea86ff1a8c18cc90a
#
#                                   from_address  \
# 3   0x0000000000000000000000000000000000000000
# 11  0x0000000000000000000000000000000000000000
# 12  0x0000000000000000000000000000000000000000
# 13  0x0000000000000000000000000000000000000000
# 14  0x0000000000000000000000000000000000000000
#
#                                     to_address value  \
# 3   0x4ffb72b66eba24521736924f87dfe10677d82286  6172
# 11  0xe8fcd7bdb10280786a5b81ffde44924b12d1f038  6173
# 12  0x8b90d68eedad4be67e1087528d5ec9003009d667  6174
# 13  0xf93040508f5748fd1d5d5ada09c079cc160d168c  6175
# 14  0x2d0623a594f25070b69f01371aff2347bfaee56d  6176
#
# ...

# %% [markdown]
# ### 3.2 Query a specific ERC20 token transfers

# %% [markdown]
# *references*:
#
# * Commond Documentations: https://ethereum-etl.readthedocs.io/en/latest/commands/
# * Token Address: https://github.com/blockchain-etl/ethereum-etl-airflow/blob/master/dags/resources/stages/seed/data/token_amendments.csv
# * More detailed: https://github.com/blockchain-etl/ethereum-etl-airflow
# * Proof-of-Reserve: https://blog.chain.link/stablecoins-and-proof-of-reserve/

# %%
#@title Token Name
Token_Name = "Dai Stablecoin" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "DAI" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x6B175474E89094C44Da98b954EedeAC495271d0F" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537388 --end-block 15537398 --provider-uri https://mainnet.infura.io/v3/d7ec1252cc2a4031848d6d1963b443a6 --output token_transfers_DAI.csv --tokens 0x6B175474E89094C44Da98b954EedeAC495271d0F
# Out:
# 2023-01-26 08:41:11,701 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:41:12,308 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:41:12,308 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:00.607553.
# 2023-01-26 08:41:12,310 - CompositeItemExporter [INFO] - token_transfer items exported: 7

# %%
df_token_transfers_DAI = pd.read_csv('./token_transfers_DAI.csv')
display(df_token_transfers_DAI.head())
# Out:
#                                 token_address  \
# 0  0x6b175474e89094c44da98b954eedeac495271d0f
# 1  0x6b175474e89094c44da98b954eedeac495271d0f
# 2  0x6b175474e89094c44da98b954eedeac495271d0f
# 3  0x6b175474e89094c44da98b954eedeac495271d0f
# 4  0x6b175474e89094c44da98b954eedeac495271d0f
#
#                                  from_address  \
# 0  0x60594a405d53811d3bc4766596efd80fd545a270
# 1  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 2  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 3  0xe2b8eb988735f7709d08b7d07b41460073904830
# 4  0xa478c2975ab1ea89e8196811f51a7b7ade33eb11
#
#                                    to_address                     value  \
# 0  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94   61632417361252428356036
# 1  0xc2e9f25be6257c210d7adf0d4cd6e3e881ba25f8  221663145131501373823561
# 2  0xa478c2975ab1ea89e8196811f51a7b7ade33eb11   30589881411700160945861
# 3  0x75bff91af9878f5ec3fede9b52d51159afc2430a   21473444552785104164598
# ...

# %% [markdown]
# ### 3.3 Query a specific ERC721 token transfers

# %% [markdown]
# ADD YOUR CODE AND TEXT BOX BELOW

# %%
#@title Token Name
Token_Name = "Ethereum Name Service" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "ENS" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537388 --end-block 15537398 --provider-uri https://mainnet.infura.io/v3/d7ec1252cc2a4031848d6d1963b443a6 --output token_transfers_ENS.csv --tokens 0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85
# Out:
# 2023-01-26 08:41:28,029 - ProgressLogger [INFO] - Started work. Items to process: 11.
# 2023-01-26 08:41:29,592 - ProgressLogger [INFO] - 11 items processed. Progress is 100%.
# 2023-01-26 08:41:29,592 - ProgressLogger [INFO] - Finished work. Total items processed: 11. Took 0:00:01.562861.
# 2023-01-26 08:41:29,594 - CompositeItemExporter [INFO] - token_transfer items exported: 8

# %%
df_token_transfers_ENS = pd.read_csv('./token_transfers_ENS.csv')
display(df_token_transfers_ENS.head())
# Out:
#                                 token_address  \
# 0  0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
# 1  0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
# 2  0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
# 3  0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
# 4  0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85
#
#                                  from_address  \
# 0  0x33388dedf79477fa33f39628bf32afd60a3ee360
# 1  0x82eb45562f991329ed2867f43fc60f0ba52c3dab
# 2  0x0000000000000000000000000000000000000000
# 3  0x283af0b28c62c092c9727f1ee09c02ca627eb7f5
# 4  0x0000000000000000000000000000000000000000
#
#                                    to_address  \
# 0  0x700e3990defb8a2efa87a7a9165c5dec57f69576
# 1  0x000000000000000000000000000000000000dead
# 2  0x283af0b28c62c092c9727f1ee09c02ca627eb7f5
# 3  0x6641f026da7cc01ce6ff5a55355f64f6345aa499
# 4  0x283af0b28c62c092c9727f1ee09c02ca627eb7f5
#
#                                                value  \
# 0  1102206615769197168569541235952498456402300283...
# ...
